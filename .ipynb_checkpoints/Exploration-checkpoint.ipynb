# %%
import explore as ex
import pandas as pd

bills = ex.get_bills()
sponsors = ex.get_sponsors()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 import explore as ex
#       2 import pandas as pd
# ----> 4 bills = ex.get_bills()
#       5 sponsors = ex.get_sponsors()
#
# File ~/Documents/mscapp/capp122/project-il-legible/exploration/explore.py:18, in get_bills()
#      17 def get_bills():
# ---> 18     return get_data_from_csv("bills")
#
# File ~/Documents/mscapp/capp122/project-il-legible/exploration/explore.py:30, in get_data_from_csv(file_fragment)
#      28 file_list = list(root_dir.rglob(f"./*/bulk_data/IL/*/*{file_fragment}.csv"))
#      29 df = None
# ---> 30 df = pd.concat((pd.read_csv(f) for f in file_list), ignore_index=True)
#      32 return df
#
# ...

# %%
unique_sponsors = pd.Series(sponsors["name"].unique(), name="Sponsors")
unique_sponsors.to_csv('unique_sponsors_103.csv', index=False, header=['Unique Sponsors'])
