# %%
import os
import explore as ex

bills = ex.get_bills()
# Out:
# Traceback (most recent call last):
#
#   File /usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[6], line 2
#     import explore as ex
#
#   File ~/Documents/mscapp/capp122/project-il-legible/exploration/explore.py:18
#     url = httpx.URL(f"{API_REF["base_url"]}{endpoint}/{id if id is not None else ''}?apikey={API_KEY}")
#                                 ^
# SyntaxError: f-string: unmatched '['
