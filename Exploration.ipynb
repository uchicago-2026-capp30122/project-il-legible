# %%
import exploration.explore as ex
import pandas as pd

bills = ex.get_bills()
sponsors = ex.get_sponsors()

# %%
unique_sponsors = pd.Series(sponsors["name"].unique(), name="Sponsors")
unique_sponsors.to_csv('unique_sponsors.csv', index=False, header=['Unique Sponsors'])
