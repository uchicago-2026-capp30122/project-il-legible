# %% [markdown]
# # Legislature Data Exploration
#
# Use this file to explore the bulk data (currently just from Open States) inside Pandas data frames. The data is pulled using methods from `explore.py` - you may add additional functions for your needs. Just reload the notebook kernel to get the most updated `explore.py` file.
#
# ## Currently Available Methods
# : `get_bills()`
# : `get_sponsors()`
# : `get_votes()`
# : `get_all_datasets()`
#
# > **Note that calling `get_all_datasets()` will pull ALL FILES specified in the INCLUDED_DATA constant within `explore.py`. Depending on the amount of bulk data you're working with, this can be time consuming. Use with caution.**

# %%
# Import Libraries

import exploration.explore as ex
import matplotlib as plot

# %%
# Get the data we'd like to explore
all_data = ex.get_all_datasets()
bills = all_data["bills"]

# %%
# Explore the data
bills["classification"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='classification'>
